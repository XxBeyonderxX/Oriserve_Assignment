# %%
# !pip install "tensorflow-text==2.13.*"

# %%
# !pip install "tf-models-official==2.13.*"

# %%
import pandas as pd
import numpy as np
import re
import spacy
# from transformers import BertTokenizer, BertForSequenceClassification
# from transformers import pipeline

# %%
dataset=pd.read_csv("Evaluation-dataset.csv")

# %%
col={"Review":1}
for i in range(1,len(dataset.axes[0])):
    for j in range(1, len(dataset.axes[1])):
        if 'positive' in str(dataset.loc[i][j]):
            sentiment=str(dataset.loc[i][j])
            col[sentiment[:-9]]=1
        if 'negative' in str(dataset.loc[i][j]):
            sentiment=str(dataset.loc[i][j])
            col[sentiment[:-9]]=1

# %%
newdata=pd.DataFrame(columns=[i for i in col])

# %%
newdata["Review"]=dataset["review"]

# %%
col={"Review":1}
for i in range(0,len(dataset.axes[0])):
    for j in range(1, len(dataset.axes[1])):
        if 'positive' in str(dataset.loc[i][j]):
            sentiment=str(dataset.loc[i][j])
            newdata[sentiment[:-9]][i]=1
        if 'negative' in str(dataset.loc[i][j]):
            sentiment=str(dataset.loc[i][j])
            newdata[sentiment[:-9]][i]=-1

# %%
newdata.fillna(0, inplace=True)

# %%
def get_labels(df):
    final=[]
    outshape=[]
    for i in df.columns:
        Y=df[i]
        Y = pd.get_dummies(Y)
        Y = Y.values
        final.append(Y)
        outshape.append(Y.shape[0])

    return final, outshape

# %%
x=newdata["Review"]
y=newdata.drop("Review", axis=1)
final, outshape = get_labels(y)

# %%
y.columns

# %%
final[0].shape

# %%
import tensorflow_hub as hub
import tensorflow as tf
import tensorflow_text as text
# bert_preprocess_model = hub.KerasLayer(tfhub_handle_preprocess)
# bert_model = hub.KerasLayer(tfhub_handle_encoder)

# %%
bert_model_name = 'small_bert/bert_en_uncased_L-4_H-512_A-8'
tfhub_handle_encoder='https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1'
tfhub_handle_preprocess='https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3'

def build_classifier_model(outshape):
  text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
  preprocessing_layer = hub.KerasLayer(tfhub_handle_preprocess, name='preprocessing')
  encoder_inputs = preprocessing_layer(text_input)
  encoder = hub.KerasLayer(tfhub_handle_encoder, trainable=False, name='BERT_encoder')
  outputs = encoder(encoder_inputs)
  net = outputs['pooled_output']
  out_layers=[]
  for i in outshape:
    out = tf.keras.layers.Dropout(0.1)(net)
    out = tf.keras.layers.Dense(8, activation="relu")(out)
    out = tf.keras.layers.Dense(i, activation="softmax",)(out)
    out_layers.append(out)

  return tf.keras.Model(text_input, outputs=out_layers)

# %%
optimizer = tf.keras.optimizers.Adam()
losses=[]
metrics=[]
for i in outshape:
  losses.append("categorical_crossentropy")
  metrics.append("accuracy")
model=build_classifier_model(outshape)
model.compile(loss=losses, optimizer=optimizer, metrics=metrics)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_mask': (None, 128)   0         ['text[0][0]']
#                              , 'input_word_ids': (None,
#                               128),
#                               'input_type_ids': (None,
#                              128)}
#
#  BERT_encoder (KerasLayer)   {'encoder_outputs': [(None   2876364   ['preprocessing[0][0]',
#                              , 128, 512),                 9          'preprocessing[0][1]',
#                               (None, 128, 512),                      'preprocessing[0][2]']
#                               (None, 128, 512),
#                               (None, 128, 512)],
#                               'sequence_output': (None,
#                               128, 512),
#                               'default': (None, 512),
#                               'pooled_output': (None, 5
#                              12)}
#
#  dropout_33 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_34 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_35 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_36 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_37 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_38 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_39 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_40 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_41 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_42 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_43 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_44 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_45 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_46 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_47 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_48 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_49 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_50 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_51 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_52 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_53 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_54 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_55 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_56 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_57 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_58 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_59 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_60 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_61 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_62 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_63 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dropout_64 (Dropout)        (None, 512)                  0         ['BERT_encoder[0][5]']
#
#  dense_66 (Dense)            (None, 8)                    4104      ['dropout_33[0][0]']
#
#  dense_68 (Dense)            (None, 8)                    4104      ['dropout_34[0][0]']
#
#  dense_70 (Dense)            (None, 8)                    4104      ['dropout_35[0][0]']
#
#  dense_72 (Dense)            (None, 8)                    4104      ['dropout_36[0][0]']
#
#  dense_74 (Dense)            (None, 8)                    4104      ['dropout_37[0][0]']
#
#  dense_76 (Dense)            (None, 8)                    4104      ['dropout_38[0][0]']
#
#  dense_78 (Dense)            (None, 8)                    4104      ['dropout_39[0][0]']
#
#  dense_80 (Dense)            (None, 8)                    4104      ['dropout_40[0][0]']
#
#  dense_82 (Dense)            (None, 8)                    4104      ['dropout_41[0][0]']
#
#  dense_84 (Dense)            (None, 8)                    4104      ['dropout_42[0][0]']
#
#  dense_86 (Dense)            (None, 8)                    4104      ['dropout_43[0][0]']
#
#  dense_88 (Dense)            (None, 8)                    4104      ['dropout_44[0][0]']
#
#  dense_90 (Dense)            (None, 8)                    4104      ['dropout_45[0][0]']
#
#  dense_92 (Dense)            (None, 8)                    4104      ['dropout_46[0][0]']
#
#  dense_94 (Dense)            (None, 8)                    4104      ['dropout_47[0][0]']
#
#  dense_96 (Dense)            (None, 8)                    4104      ['dropout_48[0][0]']
#
#  dense_98 (Dense)            (None, 8)                    4104      ['dropout_49[0][0]']
#
#  dense_100 (Dense)           (None, 8)                    4104      ['dropout_50[0][0]']
#
#  dense_102 (Dense)           (None, 8)                    4104      ['dropout_51[0][0]']
#
#  dense_104 (Dense)           (None, 8)                    4104      ['dropout_52[0][0]']
#
#  dense_106 (Dense)           (None, 8)                    4104      ['dropout_53[0][0]']
#
#  dense_108 (Dense)           (None, 8)                    4104      ['dropout_54[0][0]']
#
#  dense_110 (Dense)           (None, 8)                    4104      ['dropout_55[0][0]']
#
#  dense_112 (Dense)           (None, 8)                    4104      ['dropout_56[0][0]']
#
#  dense_114 (Dense)           (None, 8)                    4104      ['dropout_57[0][0]']
#
#  dense_116 (Dense)           (None, 8)                    4104      ['dropout_58[0][0]']
#
#  dense_118 (Dense)           (None, 8)                    4104      ['dropout_59[0][0]']
#
#  dense_120 (Dense)           (None, 8)                    4104      ['dropout_60[0][0]']
#
#  dense_122 (Dense)           (None, 8)                    4104      ['dropout_61[0][0]']
#
#  dense_124 (Dense)           (None, 8)                    4104      ['dropout_62[0][0]']
#
#  dense_126 (Dense)           (None, 8)                    4104      ['dropout_63[0][0]']
#
#  dense_128 (Dense)           (None, 8)                    4104      ['dropout_64[0][0]']
#
#  dense_67 (Dense)            (None, 10132)                91188     ['dense_66[0][0]']
#
#  dense_69 (Dense)            (None, 10132)                91188     ['dense_68[0][0]']
#
#  dense_71 (Dense)            (None, 10132)                91188     ['dense_70[0][0]']
#
#  dense_73 (Dense)            (None, 10132)                91188     ['dense_72[0][0]']
#
#  dense_75 (Dense)            (None, 10132)                91188     ['dense_74[0][0]']
#
#  dense_77 (Dense)            (None, 10132)                91188     ['dense_76[0][0]']
#
#  dense_79 (Dense)            (None, 10132)                91188     ['dense_78[0][0]']
#
#  dense_81 (Dense)            (None, 10132)                91188     ['dense_80[0][0]']
#
#  dense_83 (Dense)            (None, 10132)                91188     ['dense_82[0][0]']
#
#  dense_85 (Dense)            (None, 10132)                91188     ['dense_84[0][0]']
#
#  dense_87 (Dense)            (None, 10132)                91188     ['dense_86[0][0]']
#
#  dense_89 (Dense)            (None, 10132)                91188     ['dense_88[0][0]']
#
#  dense_91 (Dense)            (None, 10132)                91188     ['dense_90[0][0]']
#
#  dense_93 (Dense)            (None, 10132)                91188     ['dense_92[0][0]']
#
#  dense_95 (Dense)            (None, 10132)                91188     ['dense_94[0][0]']
#
#  dense_97 (Dense)            (None, 10132)                91188     ['dense_96[0][0]']
#
#  dense_99 (Dense)            (None, 10132)                91188     ['dense_98[0][0]']
#
#  dense_101 (Dense)           (None, 10132)                91188     ['dense_100[0][0]']
#
#  dense_103 (Dense)           (None, 10132)                91188     ['dense_102[0][0]']
#
#  dense_105 (Dense)           (None, 10132)                91188     ['dense_104[0][0]']
#
#  dense_107 (Dense)           (None, 10132)                91188     ['dense_106[0][0]']
#
#  dense_109 (Dense)           (None, 10132)                91188     ['dense_108[0][0]']
#
#  dense_111 (Dense)           (None, 10132)                91188     ['dense_110[0][0]']
#
#  dense_113 (Dense)           (None, 10132)                91188     ['dense_112[0][0]']
#
#  dense_115 (Dense)           (None, 10132)                91188     ['dense_114[0][0]']
#
#  dense_117 (Dense)           (None, 10132)                91188     ['dense_116[0][0]']
#
#  dense_119 (Dense)           (None, 10132)                91188     ['dense_118[0][0]']
#
#  dense_121 (Dense)           (None, 10132)                91188     ['dense_120[0][0]']
#
#  dense_123 (Dense)           (None, 10132)                91188     ['dense_122[0][0]']
#
#  dense_125 (Dense)           (None, 10132)                91188     ['dense_124[0][0]']
#
#  dense_127 (Dense)           (None, 10132)                91188     ['dense_126[0][0]']
#
#  dense_129 (Dense)           (None, 10132)                91188     ['dense_128[0][0]']
#
# ==================================================================================================
# Total params: 31812993 (121.36 MB)
# Trainable params: 3049344 (11.63 MB)
# Non-trainable params: 28763649 (109.72 MB)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
history=model.fit(x, final,
                  epochs=50,
                  batch_size=32)
